# %%
#import dependencies
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
#load and view United States Human development indicator
file = pd.read_csv("United States.csv")
#Human Development index
USA_df = pd.DataFrame(file)
USA_df
# Out:
#                                                    United States
# Life expectancy at birth (years)                            78.9
#  Age-standardized mortality rate attributed to ...         353.5
# Age-standardized mortality rate attributed to n...         492.3
# Child malnutrition, stunting (moderate or sever...           3.5
# Current health expenditure (% of GDP)                       17.1
# ...                                                          ...
# Population using safely managed sanitation serv...            90
# Ratio of education and health expenditure to mi...           6.2
# Research and development expenditure (% of GDP)              2.8
# Rural population with access to electricity (%)            100.0
# Total debt service (% of exports of goods, serv...          n.a.
#
# [172 rows x 1 columns]

# %%
USA_df.columns = ['United_States']
USA_df
# Out:
#                                                    United_States
# Life expectancy at birth (years)                            78.9
#  Age-standardized mortality rate attributed to ...         353.5
# Age-standardized mortality rate attributed to n...         492.3
# Child malnutrition, stunting (moderate or sever...           3.5
# Current health expenditure (% of GDP)                       17.1
# ...                                                          ...
# Population using safely managed sanitation serv...            90
# Ratio of education and health expenditure to mi...           6.2
# Research and development expenditure (% of GDP)              2.8
# Rural population with access to electricity (%)            100.0
# Total debt service (% of exports of goods, serv...          n.a.
#
# [172 rows x 1 columns]

# %%
USA_df.value_counts()
# Out:
# United_States
# n.a.             32
# 100.0             2
# 13.4              2
# 2.8               2
# 5.0               2
#                  ..
# 14                1
# 139               1
# 13.8              1
# 13.5              1
# 27.1              1
# Length: 130, dtype: int64

# %%
USA_df['United_States'] = USA_df['United_States'].replace(to_replace='NaN', value='none')
USA_df
# Out:
#                                                    United_States
# Life expectancy at birth (years)                            78.9
#  Age-standardized mortality rate attributed to ...         353.5
# Age-standardized mortality rate attributed to n...         492.3
# Child malnutrition, stunting (moderate or sever...           3.5
# Current health expenditure (% of GDP)                       17.1
# ...                                                          ...
# Population using safely managed sanitation serv...            90
# Ratio of education and health expenditure to mi...           6.2
# Research and development expenditure (% of GDP)              2.8
# Rural population with access to electricity (%)            100.0
# Total debt service (% of exports of goods, serv...          n.a.
#
# [172 rows x 1 columns]

# %%
USA_df.head(61)
# Out:
#                                                    United_States
# Life expectancy at birth (years)                            78.9
#  Age-standardized mortality rate attributed to ...         353.5
# Age-standardized mortality rate attributed to n...         492.3
# Child malnutrition, stunting (moderate or sever...           3.5
# Current health expenditure (% of GDP)                       17.1
# ...                                                          ...
#  Income share held by richest 10 %                          30.5
# Inequality in education (%)                                  2.8
# Inequality in income (%)                                    27.1
# Inequality in life expectancy (%)                            6.3
# Inequality-adjusted education index                        0.875
#
# [61 rows x 1 columns]

# %%
values = ['n.a.', 'NaN']
USA_df = USA_df[USA_df.United_States.isin(values) == False]
USA_df
# Out:
#                                                    United_States
# Life expectancy at birth (years)                            78.9
#  Age-standardized mortality rate attributed to ...         353.5
# Age-standardized mortality rate attributed to n...         492.3
# Child malnutrition, stunting (moderate or sever...           3.5
# Current health expenditure (% of GDP)                       17.1
# ...                                                          ...
# Population using safely managed drinking-water ...            99
# Population using safely managed sanitation serv...            90
# Ratio of education and health expenditure to mi...           6.2
# Research and development expenditure (% of GDP)              2.8
# Rural population with access to electricity (%)            100.0
#
# [140 rows x 1 columns]

# %%
USA_df = USA_df.drop(['Child marriage, women married by age 18 (% of women ages 20–24 who are married or in union)\n','n.a.'])
USA_df
# Out:
#                                                    United_States
# Life expectancy at birth (years)                            78.9
#  Age-standardized mortality rate attributed to ...         353.5
# Age-standardized mortality rate attributed to n...         492.3
# Child malnutrition, stunting (moderate or sever...           3.5
# Current health expenditure (% of GDP)                       17.1
# ...                                                          ...
# Population using safely managed drinking-water ...            99
# Population using safely managed sanitation serv...            90
# Ratio of education and health expenditure to mi...           6.2
# Research and development expenditure (% of GDP)              2.8
# Rural population with access to electricity (%)            100.0
#
# [138 rows x 1 columns]

# %%
USA_df.values
# Out:
# array([['78.9'],
#        ['353.5'],
#        ['492.3'],
#        ['3.5'],
#        ['17.1'],
#        ['3'],
#        ['10'],
#        ['81.4'],
#        ['76.3'],
#        ['0.906'],
#        ['82'],
#        ['5.6'],
#        ['139'],
#        ['6.5'],
#        ['3.0'],
#        ['16.3'],
#        ['0.900'],
#        ['16.9'],
#        ['15.7'],
#        ['5.0'],
#        ['73'],
#        ['102'],
#        ['99'],
#        ['88'],
#        ['13.4'],
#        ['13.5'],
#        ['13.4'],
#        ['96.0'],
#        ['96.1'],
#        ['96.0'],
#        ['478'],
#        ['505'],
#        ['502'],
#        ['14'],
#        ['63,826'],
#        ['50,590'],
#        ['77,338'],
#        ['62,683'],
#        ['20,575.0'],
#        ['20.7'],
#        ['0.976'],
#        ['58.6'],
#        ['0.808'],
#        ['12.1'],
#        ['41.4'],
#        ['9.4'],
#        ['15.4'],
#        ['20.5'],
#        ['30.5'],
#        ['2.8'],
#        ['27.1'],
#        ['6.3'],
#        ['0.875'],
# ...

# %%
USA_df.isna()
# Out:
#                                                     United_States
# Life expectancy at birth (years)                            False
#  Age-standardized mortality rate attributed to ...          False
# Age-standardized mortality rate attributed to n...          False
# Child malnutrition, stunting (moderate or sever...          False
# Current health expenditure (% of GDP)                       False
# ...                                                           ...
# Population using safely managed drinking-water ...          False
# Population using safely managed sanitation serv...          False
# Ratio of education and health expenditure to mi...          False
# Research and development expenditure (% of GDP)             False
# Rural population with access to electricity (%)             False
#
# [138 rows x 1 columns]

# %%
file = pd.read_excel("state_gdp.xlsx", sheet_name= "Table 3")
state_gdp_df = pd.DataFrame(file)
state_gdp_df
# Out:
#    Table 3. Current-Dollar Gross Domestic Product, by State and Region, 2020:Q1–2021:Q4  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                       United States
# ..                                                ...
# 64                                                NaN
# 65                               Overseas activity 1/
# 66  1.  Economic activity taking place outside the...
# 67                                      p Preliminary
# 68           Source. U.S. Bureau of Economic Analysis
#
#                              Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                   Millions of dollars        NaN        NaN        NaN
# 1   Seasonally adjusted at annual rates        NaN        NaN        NaN
# ...

# %%
state_gdp_df = state_gdp_df.drop([0,1,2,3,64,65,66,67,68])
state_gdp_df
# Out:
#    Table 3. Current-Dollar Gross Domestic Product, by State and Region, 2020:Q1–2021:Q4  \
# 4                                       United States
# 5                                        New England
# 6                                         Connecticut
# 7                                              Maine
# 8                                      Massachusetts
# 9                                      New Hampshire
# 10                                      Rhode Island
# 11                                           Vermont
# 12                                           Mideast
# 13                                          Delaware
# 14                              District of Columbia
# 15                                          Maryland
# 16                                         New Jersey
# 17                                           New York
# 18                                      Pennsylvania
# 19                                       Great Lakes
# ...

# %%
state_gdp_df.columns = ['State', 'Q1_2020', 'Q2_2020', 'Q3_2020', 'Q4_2020', 'Q1_2021', 'Q2_2021', 'Q3_2021', 'Q4_2021', 'per_Q1_2020', 'per_Q2_2020', 'per_Q3_2020', 'per_Q4_2020', 'per_Q1_2021', 'per_Q2_2021', 'per_Q3_2021', 'per_Q4_2021']
state_gdp_df
# Out:
#                     State   Q1_2020   Q2_2020   Q3_2020   Q4_2020   Q1_2021  \
# 4           United States  21481367  19477444  21138574  21477597  22038226
# 5            New England    1142537   1034455   1119585   1142558   1159111
# 6             Connecticut    286287    257812    278870    282722    285112
# 7                  Maine      70099     64704     70256     72027     73174
# 8          Massachusetts     600436    544140    586020    599311    610700
# 9          New Hampshire      89251     80750     88890     91593     92753
# 10          Rhode Island      61776     56289     61653     62508     62340
# 11               Vermont      34688     30758     33897     34397     35032
# 12               Mideast    3884793   3500191   3777249   3822776   3904216
# 13              Delaware      77074     71818     76815     77439     77392
# 14  District of Columbia     147340    139171    144287    147421    147830
# ...
